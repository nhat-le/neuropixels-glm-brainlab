# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import scipy.io

# %matplotlib notebook

# %%
# Read the data
data = scipy.io.loadmat('Toy/Cori_2016_12_14_unit250_ACA_new.mat')
trial = data['trialStruct']

# %%
sptrain = trial['sptrain41'][0]
stimOn = trial['stimOn'][0]
leftResponse = trial['leftResponse'][0]
rightResponse = trial['rightResponse'][0]
feedback = trial['feedback'][0]

# %%
plt.figure()
plt.plot(stimOnTimes)
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
stimOn = trial['stimOn'][0]

# %%
# Make the sptrain array
sptrainall = []
stimOnTimes = []
feedbackTimes = []
responseTimes = []
for i in range(214):
    sptrainall.append(sptrain[i][:,0] - stimOn[i][0,0])
    stimOnTimes.append([stimOn[i][0,0]])
    feedbackTimes.append([feedback[i][0,0]])
    if leftResponse[i].shape[1] > 0:
        responseTimes.append([leftResponse[i][0,0]])
    elif rightResponse[i].shape[1] > 0:
        responseTimes.append([rightResponse[i][0,0]])
    else:
        responseTimes.append([0])
plt.figure()
plt.eventplot(sptrainall, lineoffsets=1, linelengths=1.2, linewidths=2);
#plt.eventplot(stimOnTimes, color='r');
#plt.eventplot(responseTimes, color='k', linewidths=3);
#plt.eventplot(feedbackTimes, color='g', linewidths=3);
# Out:
# <img src="data:image/png;base64,..." width="640">

# %%
responseTimes
# Out:
# [[2532.2203939657797],
#  [2993.6663865111655],
#  [1629.601733862742],
#  [0],
#  [1362.7089640694692],
#  [2305.9123319530813],
#  [2512.8018107966736],
#  [0],
#  [0],
#  [1603.5385410207823],
#  [1961.295541354815],
#  [0],
#  [1408.936565332482],
#  [556.1198199844455],
#  [416.11953864239126],
#  [3135.0164193061973],
#  [0],
#  [4542.11098784242],
#  [3162.5584590422022],
#  [1826.8779430624704],
#  [0],
#  [5511.962185867418],
#  [2184.9438561316956],
#  [0],
#  [1994.7850095053923],
#  [1402.0379503156164],
#  [0],
#  [411.4481499419469],
#  [945.7915733878224],
#  [3695.1466745574635],
#  [6536.696964445526],
#  [0],
#  [4548.990704894151],
#  [848.2046926248188],
#  [3742.3560009319203],
#  [0],
#  [0],
#  [0],
#  [1551.6490459256715],
#  [1557.898631394437],
#  [8443.873894756905],
#  [1478.2045326741695],
#  [1386.6927837703997],
#  [0],
#  [0],
#  [682.581060306461],
#  [1893.7229092345547],
#  [5197.593911142576],
#  [1554.4768889371312],
#  [1800.1011647314158],
# ...

# %%
rightResponse[0]
# Out:
# array([], shape=(1, 0), dtype=float64)

# %%
plt.figure()
plt.eventplot([[1,2,3], [1,3,4,5,6,7]])
# Out:
# <img src="data:image/png;base64,..." width="512">
# ...
