# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd
import glob

# %matplotlib notebook

# %%
# Read a brain location
files = glob.glob('./*/*Location.tsv')
len(files)
# Out:
# 39

# %%
plt.figure(figsize=(10,10))
for i in range(16):
    tbl = pd.read_csv(files[i], sep='\t')
    plt.subplot(4,4,i+1)
    plt.plot(tbl.ccf_ap, label='ap')
    plt.plot(tbl.ccf_dv, label='dv')
    plt.plot(tbl.ccf_lr, label='lr')
    plt.legend()
# Out:
# <img src="data:image/png;base64,..." width="1000">

# %%
# Document all brain locations
area_dict = {}
for i in range(len(files)):
    session = files[i].split('\\')[1]
    tbl = pd.read_csv(files[i], sep='\t')
    area_dict[session] = tbl.allen_ontology.unique()

# %%
area_dict
# Out:
# {'Cori_2016-12-14': array(['LS', 'root', 'ACA', 'MOs', 'CA3', 'DG', 'SUB', 'VISp'],
#        dtype=object),
#  'Cori_2016-12-17': array(['root', 'CA1', 'VISl', 'POST', 'VISpm'], dtype=object),
#  'Cori_2016-12-18': array(['SPF', 'MG', 'LP', 'root', 'DG', 'CA1', 'VISam', 'MRN', 'NB',
#         'POST', 'VISp'], dtype=object),
#  'Forssmann_2017-11-01': array(['VPL', 'TH', 'LGd', 'DG', 'SUB', 'VISp', 'CA1', 'VISa', 'LSr',
#         'ACA', 'MOs'], dtype=object),
#  'Forssmann_2017-11-02': array(['root', 'CA1', 'VISa', 'DG', 'SUB', 'OLF', 'ORB', 'PL', 'ACA',
#         'MOs'], dtype=object),
#  'Forssmann_2017-11-04': array(['root', 'AUD', 'SSp', 'CA1', 'TH'], dtype=object),
#  'Forssmann_2017-11-05': array(['root', 'VPL', 'LD', 'CA3', 'PIR', 'EPd', 'CP', 'SSp'],
#        dtype=object),
#  'Hench_2017-06-15': array(['LSr', 'root', 'TT', 'ILA', 'PL', 'MOs', 'PO', 'LD', 'LP', 'CA3',
#         'DG', 'CA1', 'VISa', 'SUB', 'VISp'], dtype=object),
# ...
